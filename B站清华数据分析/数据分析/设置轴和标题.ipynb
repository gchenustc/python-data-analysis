# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager

# %%
y1 = pd.Series(np.random.randint(0,10,10))
font = font_manager.FontProperties(fname=r"C:\\Windows\\Fonts\\msyh.ttc",size=20)
plt.plot(y1)
plt.title("折线图",fontproperties=font)
# Out:
# Text(0.5, 1.0, '折线图')

# %%
avenger = [17974.4,50918.4,30033.0,40329.1,52330.2,19833.3,11902.0,24322.6,47521.8,32262.0,22841.9,12938.7,4835.1,3118.1,2570.9,2267.9,1902.8,2548.9,5046.6,3600.8]
len(avenger)
# Out:
# 20

# %%
font.set_size(10)
plt.figure(figsize=(20,10))
plt.plot(avenger,marker="o",lw=3)
plt.title("复仇者联盟4票房走向",fontproperties=font)
plt.xticks(range(20),["%d day" % x for x in range(1,21)])
plt.xlabel("days")
plt.ylabel("box office(unit: ten thousand)")
plt.grid(True)
plt.show()
