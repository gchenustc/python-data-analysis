# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
y = [np.random.randint(10) for x in range(20)]
x = range(5,25)
df = pd.DataFrame({
    "a":[np.random.randint(10) for x in range(20)],
    "b":range(5,25)
    })

# %%
plt.plot(y)

# %%
plt.plot(x,y)

# %%
plt.plot("b","a","",data=df)

# %%
plt.plot("b","a","--c",data=df)

# %%
plt.plot("b","a",":",data=df,color="red")
