# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
with sns.axes_style({"axes.facecolor":"g","axes.edgecolor":"k","axes.grid":False,"axes.labelcolor":"b"}):
    g1 = sns.FacetGrid(data,col="day",col_wrap=2,hue="sex",height=4,aspect=1.5)
    g1.map(sns.regplot,"total_bill","tip")

# %%
sns.set_style("ticks")
g1 = sns.FacetGrid(data,col="day",col_wrap=2,hue="sex",height=4,aspect=1.5)
g1.map(sns.regplot,"total_bill","tip")

# %%
sns.set(rc={"lines.linewidth":10},style="dark", font="SimHei", font_scale=2)
sns.lmplot(x = "total_bill", y = "tip", data=data)
