# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
font = FontProperties(fname=r"C:\\Windows\\Fonts\\msyh.ttc",size=12)
movies = {
    "流浪地球":40.78, 
    "飞驰人生":15.77,
    "疯狂的外星人":20.83, 
    "新喜剧之王": 6.10, 
    "廉政风云":1.10, 
    "神探蒲松龄":1.49, 
    "小猪佩奇过大年": 1.22,
    "熊出没·原始时代":6.71 
         }
x = list(movies.keys())
y = list(movies.values())
plt.figure(figsize=(14,7),dpi=300)
plt.bar(x,y,width=-0.5, align="edge", color="#0a8cae")
plt.xticks(fontproperties=font)
plt.yticks(range(0,45,5),["%d亿" % x for x in range(0,45,5)],fontproperties=font)
# Out:
# ([<matplotlib.axis.YTick at 0x1e0889671f0>,
#   <matplotlib.axis.YTick at 0x1e088755fd0>,
#   <matplotlib.axis.YTick at 0x1e088c51310>,
#   <matplotlib.axis.YTick at 0x1e088d5e250>,
#   <matplotlib.axis.YTick at 0x1e088c90d30>,
#   <matplotlib.axis.YTick at 0x1e088c511f0>,
#   <matplotlib.axis.YTick at 0x1e088ce9b20>,
#   <matplotlib.axis.YTick at 0x1e088e402b0>,
#   <matplotlib.axis.YTick at 0x1e088e40ee0>],
#  [Text(0, 0, '0亿'),
#   Text(0, 5, '5亿'),
#   Text(0, 10, '10亿'),
#   Text(0, 15, '15亿'),
#   Text(0, 20, '20亿'),
#   Text(0, 25, '25亿'),
#   Text(0, 30, '30亿'),
#   Text(0, 35, '35亿'),
#   Text(0, 40, '40亿')])
