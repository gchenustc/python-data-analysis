# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import *
import os

# %%
x = np.linspace(0,20)
plt.plot(np.sin(x),label="sin")
plt.plot(np.cos(x),label="cons")
plt.plot(np.random.permutation(50)/50,label="permutation")
plt.legend()

# %% [markdown]
# ## 设置图例位置_plt.legend(loc='lower left')
# 0: ‘best'
#
# 1: ‘upper right'
#
# 2: ‘upper left'
#
# 3: ‘lower left'
#
# 4: ‘lower right'
#
# 5: ‘right'
#
# 6: ‘center left'
#
# 7: ‘center right'
#
# 8: ‘lower center'
#
# 9: ‘upper center'
#
# 10: ‘center'

# %%
x = np.linspace(0,20)
plt.plot(np.sin(x),label="sin")
plt.plot(np.cos(x),label="cons")
plt.plot(np.random.permutation(50)/50,label="permutation")
plt.legend(loc = "center right")

# %% [markdown]
# ## 设置图例边框,背景,标题

# %%
x = np.linspace(0,20)
plt.plot(np.sin(x),label="sin")
plt.plot(np.cos(x),label="cons")
plt.plot(np.random.permutation(50)/50,label="permutation")
plt.legend(loc = "best", frameon=True ,facecolor="blue", edgecolor="r", title="test")
